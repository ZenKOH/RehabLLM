# %% [markdown]
# # Training smoke test
#
# Load the small configuration, inspect parameter count, then run the CLI trainer once a tokenised corpus exists.

# %%
from rehab_minillm.config import load_config
from rehab_minillm.model import RehabMiniLLM

cfg = load_config("../configs/small.yaml")
model = RehabMiniLLM(cfg.model)
print(f"Parameters: {model.parameter_count():,}")

# %% [markdown]
# Run training from the repository root:
#
# ```bash
# python scripts/train_model.py --config configs/tiny.yaml
# ```
